# %%
############################ explo ratery data analysis########################
1.pandas (data frame analysis)
2.numpy (number python math package)
3.matpotlib (ploting/graph/visuvlization)
4.seabron (ploating)
5.plotly (ploating)
6.bokhe (ploating)
############################# Machine learn#####################################
7.scikit-learn (m1 models will avialable)
8.ststs    (statistical models)

###########################Deeplearning################################
9.Tenserflow        (developed by google)
10.keras
11.torch
12.opencv            (computer  vision)  opencv:sendex
    
####################### Nlp #######################################
13.NLTk   (nuatural language toolkit)
14.scipy

#########################GenAI(llm)##################################
############################(prompt Engineering)####################
15.chatgpt is developed by openAI + Azure
16.mekarsuite is developed by google
17.Gemini is developed by google

################################## company based################################
18.HuggingFace
    Transformers BERT models
    ML   DL  NLP  all tasks it will do
19.AllenNLP

#################################### speasial packeges#############################
20.random
21.time
22.math
23.API
24.Flask
    streamlit
25.UI APPs

# %% [markdown]
# hello

# %%
Data Analysis
ML
DL
NLP
bert:Transformers:
LLM:GenAI

# %%
print(90)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# fill flosder
# file name
# file extetion
file_location="C:\\Users\\sunil\\Downloads\\Visadataset - Visadataset.csv"
pd.read_csv(file_location)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
file_path="C:\\Users\\sunil\\Downloads\\naresh it\\datascience\\Visadataset.csv.csv"
pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path=""
